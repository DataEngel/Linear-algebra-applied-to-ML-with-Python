# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
plt.style.use('classic')

imagen = Image.open(".\\imagenes\\almari.jpg")

plt.imshow(imagen)

# %%
imagen_gr = imagen.convert('LA')
print(imagen_gr)
# Out:
# <PIL.Image.Image image mode=LA size=6000x4002 at 0x116D7547B20>

# %%
imagen_mat = np.array(list(imagen_gr.getdata(band=0)), float)
print(imagen_mat)
# Out:
# [44. 44. 43. ... 37. 37. 36.]

# %%
imagen_mat.shape = (imagen_gr.size[1], imagen_gr.size[0])
print(imagen_mat)
# Out:
# [[44. 44. 43. ... 54. 54. 53.]
#  [43. 43. 43. ... 56. 56. 55.]
#  [42. 42. 42. ... 56. 55. 54.]
#  ...
#  [32. 33. 35. ... 37. 37. 37.]
#  [35. 35. 34. ... 37. 37. 36.]
#  [35. 35. 34. ... 37. 37. 36.]]

# %%
print(imagen_mat.shape)
# Out:
# (4002, 6000)

# %%
plt.imshow(imagen_mat, cmap = 'gray')
plt.show()

# %%
imagen_mat_2 = imagen_mat / 10
print(imagen_mat_2)
# Out:
# [[4.4 4.4 4.3 ... 5.4 5.4 5.3]
#  [4.3 4.3 4.3 ... 5.6 5.6 5.5]
#  [4.2 4.2 4.2 ... 5.6 5.5 5.4]
#  ...
#  [3.2 3.3 3.5 ... 3.7 3.7 3.7]
#  [3.5 3.5 3.4 ... 3.7 3.7 3.6]
#  [3.5 3.5 3.4 ... 3.7 3.7 3.6]]

# %%
plt.imshow(imagen_mat_2)
plt.show()

# %%
plt.imshow(imagen_mat_2, cmap="gray")
plt.show()

# %%
print(np.max(imagen_mat_2))
print(np.max(imagen_mat))
# Out:
# 25.5
# 255.0

# %%
print(np.min(imagen_mat_2))
print(np.min(imagen_mat))
# Out:
# 0.9
# 9.0
